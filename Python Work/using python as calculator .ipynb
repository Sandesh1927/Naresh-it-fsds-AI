# %%
2+2
# Out:
# 4

# %%
50-5*6
# Out:
# 20

# %%
(50-5*6)/4
# Out:
# 5.0

# %%
8/5 # division always returns a flaoting point no
# Out:
# 1.6

# %%
17/3
# Out:
# 5.666666666666667

# %%
17//3
# Out:
# 5

# %%
17%3
# Out:
# 2

# %%
5*3+2
# Out:
# 17

# %%
5**2
# Out:
# 25

# %%
2**7
# Out:
# 128

# %%
width =20
height=5*9
width*height
# Out:
# 900

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 n
#
# NameError: name 'n' is not defined

# %%
4*3.75-1
# Out:
# -15.0

# %%
tax=12.5/100
price=100.50
price*tax
price
# Out:
# 100.5

# %%
price +_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 price +_
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
round(_,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 round(_,2)
#
# TypeError: type str doesn't define __round__ method

# %% [markdown]
# text

# %%
'spam eggs'
# Out:
# 'spam eggs'

# %%
'paris rabbit got your back:)!yay'
# Out:
# 'paris rabbit got your back:)!yay'

# %%
'2002'
# Out:
# '2002'

# %%
'doesn\'t'
# Out:
# "doesn't"

# %%
"doesn't"
# Out:
# "doesn't"

# %%
'"yes,"they said.'
# Out:
# '"yes,"they said.'

# %%
"'isn't'they said"
# Out:
# "'isn't'they said"

# %%
s='first line.\nsecond line'
s
# Out:
# 'first line.\nsecond line'

# %%
print(s)
# Out:
# first line.
# second line

# %%
print('c:\some\nname')
# Out:
# c:\some
# name
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\sande\AppData\Local\Temp\ipykernel_10904\1961778437.py:1: SyntaxWarning: invalid escape sequence '\s'
#   print('c:\some\nname')

# %%
print(r'c:\some\name')
# Out:
# c:\some\name

# %%
print='("""\)'
print
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\)'
# <>:1: SyntaxWarning: invalid escape sequence '\)'
# C:\Users\sande\AppData\Local\Temp\ipykernel_10904\3648154127.py:1: SyntaxWarning: invalid escape sequence '\)'
#   print='("""\)'
# '("""\\)'

# %%
#3 times 'un', followed by  'ium' +'ium'
3* 'un'+'ium'
# Out:
# 'unununium'

# %%
'py''thon'
# Out:
# 'python'

# %%
text=('put serval strings within parentheses' 'to have them joined together')
text
# Out:
# 'put serval strings within parenthesesto have them joined together'

# %%
prefix='py'
prefix='thon'
# Out:
# 'thon'

# %%
s('un' *3)'ium'
s
# Out:
#   Cell In[79], line 1
#     s('un' *3)'ium'
#               ^
# SyntaxError: invalid syntax

# %%
prefix+'thon'
# Out:
# 'thonthon'

# %%
word='python'
word[4]
# Out:
# 'o'

# %%
word[5]
# Out:
# 'n'

# %%
word[-1]
# Out:
# 'n'

# %%
word[0:2]
# Out:
# 'py'

# %%
word[:6]
# Out:
# 'python'

# %%
word[:2] +word[2:]
# Out:
# 'python'

# %%
word[:7]
# Out:
# 'python'

# %%
word[42]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 word[42]
#
# IndexError: string index out of range

# %%
word[4:42]
# Out:
# 'on'

# %%
word[42:]
# Out:
# ''

# %%
word[0]'j'
# Out:
#   Cell In[100], line 1
#     word[0]'j'
#            ^
# SyntaxError: invalid syntax

# %%
word[2:]='py'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 word[2:]='py'
#
# TypeError: 'str' object does not support item assignment

# %%
'j'+ word[1:]
# Out:
# 'jython'

# %%
word[:2]+'py'
# Out:
# 'pypy'

# %%
s='supercalifragilisticexpicalidocious'
len(s)
# Out:
# 35

# %%
sqares=[1,4,9,16,25]
sqares
# Out:
# [1, 4, 9, 16, 25]

# %%
sqares[0]
# Out:
# 1

# %%
sqares[-1]
# Out:
# 25

# %%
cubes=[1,8,27,65,125]
4**
# Out:
# 16

# %%
cubes[2]=16
cubes
# Out:
# [1, 8, 16, 65, 125]

# %%
cubes.append(216)
cubes.append(7**3)
cubes
# Out:
# [1, 8, 16, 65, 125, 216, 343]

# %%
rgb=["red","green","blue"]
rgba=rgb
id(rgb)==id(rgba)
rgba.append("Alph")
rgb
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[144], line 3
#       1 rgb=["red","green","blue"]
#       2 rgba=rgb
# ----> 3 id('rgb')==id('rgba')
#       4 rgba.append("Alph")
#       5 rgb
#
# TypeError: 'bool' object is not callable

# %%
letters=['a','b','c','d','e','f','g']
letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
#replace some values
letters[2:5]= ['C','D','E']
letters
# Out:
# ['a', 'b', 'C', 'D', 'E', 'f', 'g']

# %%
#now remove them
letters[2:5]=[]
letters
# Out:
# ['a', 'b']

# %%
#clean the list by replacing all the elements with an empty list
letters[:]=[]
letters
# Out:
# []

# %%
letters=['a','b','c','d','e']
len(letters)
# Out:
# 5
