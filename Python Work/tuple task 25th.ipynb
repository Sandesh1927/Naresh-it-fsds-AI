# %% [markdown]
# tuple creation

# %%
tup1=()

# %%
tup2=(10,30,60)

# %%
tup3=(10,77,30,66,89)

# %%
tup4=('one','two','three')

# %%
tup5=('san',25,[50,100],(150,90))

# %%
tup6=(100,'san',17.765)

# %%
tup7=('san',25,[50,100],[150,90],{'don','david'},(99,22,33))

# %%
len(tup7)
# Out:
# 6

# %% [markdown]
# tuple indexing

# %%
tup2[0]
# Out:
# 0

# %%
tup4[0]
# Out:
# 'one'

# %%
tup4[0][0]
# Out:
# 'o'

# %%
tup4[-1]
# Out:
# 'three'

# %%
tup5[-1]
# Out:
# (150, 90)

# %% [markdown]
# tuple slicing

# %%
mytuple = ('one','two','three','four','five','six','seven','eight')

# %%
mytuple[0:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5]
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2]
# Out:
# ('one', 'two')

# %% [markdown]
# remove and change and item

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytuple[0]=1
# Out:
#   Cell In[96], line 1
#     del mytuple[0]=1
#                   ^
# SyntaxError: invalid syntax

# %%
del  mytuple

# %% [markdown]
# Loop through a tuple

# %%
mytuple=('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for i in mytuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# tuple membereship

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
'one' in mytuple
# Out:
# True

# %%
'ten' in mytuple
# Out:
# False

# %%
if 'three' in mytuple:
    print('three is present in the tuple')
else:
    print('three is not present in the tuple')
# Out:
# three is present in the tuple

# %%
if 'eleven'in mytuple:
    print('eleven is present in the tuple')
else:
    print('eleven is not present in my tuple')
# Out:
# eleven is not present in my tuple

# %% [markdown]
# index position

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple.index('one')
# Out:
# 0

# %%
mytuple.index('five')
# Out:
# 4

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple1=('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')
mytuple1.index('one')
# Out:
# 0

# %% [markdown]
# shorting

# %%
mytuple2=(43,67,99,12,6,90,67)

# %%
sorted(mytuple2)
# Out:
# [6, 12, 43, 67, 67, 90, 99]

# %%
sorted(mytuple2,reverse=True)
# Out:
# [99, 90, 67, 67, 43, 12, 6]
