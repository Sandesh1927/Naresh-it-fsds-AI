# %%
# print is use for answer

# %%
a=10
b=20
a
b
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(44)
print(20,50)
print('sandesh')
print(20,50,'sandesh')
# Out:
# 44
# 20 50
# sandesh
# 20 50 sandesh

# %%
num1=20
num2=30
add=num1+num2
print(add)
# Out:
# 50

# %% [markdown]
# print result with string

# %%
num1=20
num2=30
add=num1+num2
print('the addition of' ,num1, 'and' ,num2,' is' ,add)
# Out:
# the addition of 20 and 30  is 50

# %%
name='sandesh'
age=23
city='kolhapur'
print('my name is',name,'and i am',age,'year old fraom',city)
# Out:
# my name is sandesh and i am 23 year old fraom kolhapur

# %% [markdown]
# print format method

# %%
num1=20
num2=30
add=num1+num2
print('the addition of {}and{} is={}'.format(num1,num2,add))
# Out:
# the addition of 20and30 is=50

# %%
name='sandesh'
age=20
city='kolhapur'
print('hello my name is,{}and i am{}years old from{}'.format(name,age,city))
# Out:
# hello my name is,sandeshand i am20years old fromkolhapur

# %%
num1=100
num2=25
num3=333
avg=(num1+num2+num3)/3
avg1=round((num1+num2+num3)/3,2)
print('the avg of {},{}, and {} is={}or{}'.format(num1,num2,num3,avg,avg1))
# Out:
# the avg of 100,25, and 333 is=152.66666666666666or152.67

# %%
round(avg,2)
# Out:
# 152.67

# %% [markdown]
# more short format metythod(f string method)

# %%
num1=20
num2=30
add=num1+num2
print(f'the addition of {num1} and {num2} is={add}')
# Out:
# the addition of 20 and 30 is=50

# %%
name='sandesh'
age='20'
city='kolhapur'
print(f'my name is {name} and i am {age} yrs old from {city}')
# Out:
# my name is sandesh and i am 20 yrs old from kolhapur

# %%
num1=100
num2=25
num3=333
avg=round((num1+num2+num3)/3,1)
print(f'the avg of {num1},{num2},and {num3} is= {avg}')
# Out:
# the avg of 100,25,and 333 is= 152.7

# %% [markdown]
# # lete combine all

# %%
num1=10
num2=20
add=num1+num2
print('the addition of',num1,'and',num2,'is',add)
print('the addition of {} and {} is={}'.format(num1,num2,num3))
print(f'the addition kof {num1} and {num2} is={add} ')
# Out:
# the addition of 10 and 20 is 30
# the addition of 10 and 20 is=333
# the addition kof 10 and 20 is=30

# %% [markdown]
# End statement

# %%
print('hello')   #statement1
print('good moorging')  #statement2
# i want to print like-hello good moorging
# Out:
# hello
# good moorging

# %%
print('hello', end=' ')
print(' good moorning')
# Out:
# hello  good moorning

# %% [markdown]
# Seprator

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print('hello','hai','how are you',sep=' & ')
# Out:
# hello & hai & how are you

# %%
print('hello','hai','how are you',sep=' @ ')
# Out:
# hello @ hai @ how are you

# %%
print('hello,','hai','how are you',sep=' ')
# Out:
# hello, hai how are you

# %%
print(3,'.')
# Out:
# 3 .

# %%
print(3,'.',sep='')
# Out:
# 3.

# %%
print(1,2,end=' ')
print(3,'.',sep='')
# Out:
# 1 2 3.
