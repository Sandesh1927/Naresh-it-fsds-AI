# %%
import sys 
import keyword
import operator
from datetime import datetime
import os

# %% [markdown]
# keywords

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# identifier

# %%
1var=10 #identifier can't start with adigit
# Out:
#   Cell In[7], line 1
#     1var=10
#     ^
# SyntaxError: invalid decimal literal

# %%
val@=20 #identifier can't start with symbol
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 val@=20
#
# NameError: name 'val' is not defined

# %%
import=125 # keywords can't be used as identifier
# Out:
#   Cell In[9], line 1
#     import=125
#           ^
# SyntaxError: invalid syntax

# %%
""" correct way of defining an identifier 
(identifier can be a combition of letters in lowercase (a to z) or uppercase   )
"""
val2=10

# %%
val_=99

# %% [markdown]
# comments in python

# %%
#single line comment
val1=10

# %%
# multiple
# line
# comment
val1=10

# %%
'''
multiple
line
comment
'''
val1=10

# %% [markdown]
# statements

# %%
p=20
q=20
r=q
p, type(p),hex(id(q))
# Out:
# (20, int, '0x7ffb5da52c18')

# %%
q,type(q),hex(id(q))
# Out:
# (20, int, '0x7ffb5da52c18')

# %%
r,type(r),hex(id(r))
# Out:
# (20, int, '0x7ffb5da52c18')

# %%
p=20
p=p +10
p
# Out:
# 30

# %% [markdown]
# variable assigment

# %%
intvar=10
floatvar=2.57
strvar="sandesh"
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# sandesh

# %% [markdown]
# multiple assignment

# %%
intvar,floatvar,strvar=10,2.25,"sandesh"
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.25
# sandesh

# %%
p1=p2=p3=p4=40
print(p1,p2,p3,p4)
# Out:
# 40 40 40 40

# %% [markdown]
# data types

# %% [markdown]
# numeric

# %%
val1=10
print(val1)
print(type(val1))
print(sys.getsizeof(val1))
# Out:
# 10
# <class 'int'>
# 28
